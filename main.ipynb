# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk(r'C:\Users\bazar\Documents\data\input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\bazar\Documents\data\input\aug_test.csv
# C:\Users\bazar\Documents\data\input\aug_train.csv
# C:\Users\bazar\Documents\data\input\sample_submission.csv

# %%
df = pd.read_csv(r'C:\Users\bazar\Documents\data\input\aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender
# 0             8949  city_103                   0.920   Male  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level
# 0      Has relevent experience       no_enrollment        Graduate  \
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
len('1111111111111111111')
# Out:
# 19

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender
# 0             8949  city_103                   0.920   Male  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level
# 0      Has relevent experience       no_enrollment        Graduate  \
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df['target']
# Out:
# 0        1.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 19153    1.0
# 19154    1.0
# 19155    0.0
# 19156    0.0
# 19157    0.0
# Name: target, Length: 19158, dtype: float64

# %%
df['target'].value_counts()
# Out:
# target
# 0.0    14381
# 1.0     4777
# Name: count, dtype: int64

# %%
sum([0,0,1,1])
# Out:
# 2

# %%
df['target'].sum()
# Out:
# 4777.0

# %%
df['target'].count()
# Out:
# 19158

# %%
len(df['target'])
# Out:
# 19158

# %%
df['target'].sum() / len(df['target'])
df['target'].mean()
df.head()
# Out:
#    enrollee_id      city  city_development_index gender
# 0         8949  city_103                   0.920   Male  \
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level
# 0  Has relevent experience       no_enrollment        Graduate  \
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job
# 0             STEM        >20          NaN             NaN            1  \
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender
# 0             8949  city_103                   0.920   Male  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level
# 0      Has relevent experience       no_enrollment        Graduate  \
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.groupby('gender')['target'].agg(['count','mean'])
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender
# 0             8949  city_103                   0.920   Male  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level
# 0      Has relevent experience       no_enrollment        Graduate  \
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.groupby('education_level')['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117

# %%
df.groupby('education_level')['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education_level'>

# %%
def get_gradute(val):
    if val == 'Graduate':
        return 1
    return 0

# %%
get_gradute('Graduate')
# Out:
# 1

# %%
get_gradute('Gleb')
# Out:
# 0

# %%
df['graduate'] = df['education_level'].apply(get_gradute)

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender
# 0             8949  city_103                   0.920   Male  \
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level
# 0      Has relevent experience       no_enrollment        Graduate  \
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.groupby('graduate')['target'].agg(['count','mean'])
# Out:
#           count      mean
# graduate
# 0          7560  0.202646
# 1         11598  0.279790

# %%
df.groupby('training_hours')['target'].agg(['count','mean'])
# Out:
#                 count      mean
# training_hours
# 1                   9  0.222222
# 2                  96  0.260417
# 3                 119  0.268908
# 4                 224  0.169643
# 5                 107  0.242991
# ...               ...       ...
# 328                11  0.181818
# 330                11  0.090909
# 332                12  0.333333
# 334                11  0.181818
# 336                11  0.272727
#
# [241 rows x 2 columns]

# %%
df['training_hours_bin'] = pd.cut(df['training_hours'],5)

# %%
df.groupby('training_hours_bin')['target'].agg(['count','mean'])
# Out:
#                     count      mean
# training_hours_bin
# (0.665, 68.0]       12544  0.255102
# (68.0, 135.0]        4374  0.243713
# (135.0, 202.0]       1459  0.244003
# (202.0, 269.0]        459  0.187364
# (269.0, 336.0]        322  0.214286

# %%
df['target'].value_counts()
# Out:
# target
# 0.0    14381
# 1.0     4777
# Name: count, dtype: int64

# %%
df['training_hours'].value_counts()
# Out:
# training_hours
# 28     329
# 12     292
# 18     291
# 22     282
# 50     279
#       ...
# 266      6
# 234      5
# 272      5
# 286      5
# 238      4
# Name: count, Length: 241, dtype: int64

# %%
df['training_hours'].hist(bins=10)
# Out:
# <Axes: >

# %%
df['training_hours_bin'] = pd.cut(df['training_hours'],10)

# %%
df.groupby('training_hours_bin')['target'].agg(['count','mean'])
# Out:
#                     count      mean
# training_hours_bin
# (0.665, 34.5]        7262  0.253787
# (34.5, 68.0]         5282  0.256910
# (68.0, 101.5]        2784  0.238865
# (101.5, 135.0]       1590  0.252201
# (135.0, 168.5]       1040  0.242308
# (168.5, 202.0]        419  0.248210
# (202.0, 235.5]        293  0.197952
# (235.5, 269.0]        166  0.168675
# (269.0, 302.5]        133  0.255639
# (302.5, 336.0]        189  0.185185

# %%
df['training_hours_bin'] = pd.cut(df['training_hours'],5)

# %%
df.groupby('training_hours_bin')['target'].agg(['count','mean'])
# Out:
#                     count      mean
# training_hours_bin
# (0.665, 68.0]       12544  0.255102
# (68.0, 135.0]        4374  0.243713
# (135.0, 202.0]       1459  0.244003
# (202.0, 269.0]        459  0.187364
# (269.0, 336.0]        322  0.214286

# %%
df.groupby('training_hours_bin')['target'].agg(['mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='training_hours_bin'>

# %%
df['training_hours_bin_q'] = pd.qcut(df['training_hours'],5)

# %%
df.groupby('training_hours_bin_q')['target'].agg(['count','mean'])
# Out:
#                       count      mean
# training_hours_bin_q
# (0.999, 19.0]          3849  0.251234
# (19.0, 37.0]           3949  0.255001
# (37.0, 58.0]           3758  0.261841
# (58.0, 101.0]          3772  0.240456
# (101.0, 336.0]         3830  0.238120

# %%
df.groupby('training_hours_bin_q')['target'].agg(['mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='training_hours_bin_q'>

# %%
df.isna().mean()
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# gender                    0.235306
# relevent_experience       0.000000
# enrolled_university       0.020148
# education_level           0.024011
# major_discipline          0.146832
# experience                0.003393
# company_size              0.309949
# company_type              0.320493
# last_new_job              0.022080
# training_hours            0.000000
# target                    0.000000
# graduate                  0.000000
# training_hours_bin        0.000000
# training_hours_bin_q      0.000000
# dtype: float64

# %%
df.groupby('gender',dropna=False)['target'].agg(['count','mean'])
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119
